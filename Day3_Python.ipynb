# %% [markdown]
# <a href="https://colab.research.google.com/github/pselvashankar/GenAI-SE/blob/Python-Day3/Day3_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('My First Program')
# Out:
# My First Program

# %%
print("This is my Day 3 python starting")
# Out:
# This is my Day 3 python starting

# %%
#my first python program for Day 3

# %%
Print('Test print for Python')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-961916496.py in <cell line: 0>()
# ----> 1 Print('Test print for Python')
#
# NameError: name 'Print' is not defined

# %%
print('Test Print for Python')
# Out:
# Test Print for Python

# %%
TestVar=55

# %%
TestVar
# Out:
# 55

# %%
fruit=["banana","apple","orange"]
print(fruit)
# Out:
# ['banana', 'apple', 'orange']

# %%
fruit.append("grape")
fruit
# Out:
# ['banana', 'apple', 'orange', 'grape']

# %%
fruit[2]
# Out:
# 'orange'

# %%
fruit[2]="guava"
fruit
# Out:
# ['banana', 'apple', 'guava', 'grape']

# %%
fruit.remove(fruit[1])
fruit
# Out:
# ['banana', 'guava', 'grape']

# %%
color=("a","b","c","b")
color
# Out:
# ('a', 'b', 'c', 'b')

# %%
color.count("b")
# Out:
# 2

# %%
color.index("c")
# Out:
# 2

# %%
test={'a',1,'b',2}
test
# Out:
# {1, 2, 'a', 'b'}

# %%
test.add(5)
test
# Out:
# {1, 2, 5, 'a', 'b'}

# %%
test.remove(2)
test
# Out:
# {1, 5, 'a', 'b'}

# %%
emp={"name":"Selva","age":"40","dept":"Acc"}
emp
# Out:
# {'name': 'Selva', 'age': '40', 'dept': 'Acc'}

# %%
type(emp)
# Out:
# dict

# %%
emp['name']
# Out:
# 'Selva'

# %%
emp.items()
# Out:
# dict_items([('name', 'Selva'), ('age', '40'), ('dept', 'Acc')])

# %%
emp.values()
# Out:
# dict_values(['Selva', '40', 'Acc'])

# %%
emp.keys()
# Out:
# dict_keys(['name', 'age', 'dept'])

# %%
emp["name"]="shankar"

# %%
emp.values()
# Out:
# dict_values(['shankar', '40', 'Acc'])

# %%
emp={"name":"selva","age":"40","native":"nkl","name":"shankar"}

# %%
emp
# Out:
# {'name': 'shankar', 'age': '40', 'native': 'nkl'}

# %%
emp.get("age")
# Out:
# '40'

# %%
print(len(emp))
# Out:
# 1

# %%
emp.copy()
# Out:
# {'native': 'nkl'}

# %%
emp["name"]="Slva"
emp
# Out:
# {'native': 'nkl', 'name': 'Slva'}

# %%
emp["dept"]="sss"
emp
# Out:
# {'native': 'nkl', 'name': 'Slva', 'dept': 'sss'}

# %%
emp["age"]="40"
emp
# Out:
# {'native': 'nkl', 'name': 'Slva', 'dept': 'sss', 'age': '40'}

# %%
emp.pop("name")
# Out:
# 'Slva'

# %%
emp
# Out:
# {'native': 'nkl', 'dept': 'sss', 'age': '40'}

# %%
emp.popitem('age')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1897962361.py in <cell line: 0>()
# ----> 1 emp.popitem('age')
#
# TypeError: dict.popitem() takes no arguments (1 given)

# %%
emp
# Out:
# {'native': 'nkl', 'dept': 'sss', 'age': '40'}

# %%
emp.popitem[2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-828085573.py in <cell line: 0>()
# ----> 1 emp.popitem[2]
#
# TypeError: 'builtin_function_or_method' object is not subscriptable

# %%
emp["blood"]="A"
emp
# Out:
# {'native': 'nkl', 'dept': 'sss', 'age': '40', 'blood': 'A'}

# %%
emp["name"]="sssva"
emp
# Out:
# {'native': 'nkl', 'dept': 'sss', 'age': '40', 'blood': 'A', 'name': 'sssva'}

# %%
emp.popitem()
emp
# Out:
# {'native': 'nkl', 'dept': 'sss', 'age': '40', 'blood': 'A'}

# %%
Selva=int(input("how much you have?? "))

if Selva>=30:
  print("Selva has more money")
else:
    print("Selva has less money")
# Out:
# how much you have?? 50
# Selva has more money

# %%
Selva=int(input("how much you have?? "))
if (Selva>20 and Selva <30):
  print("Selva has 20 to 30")
elif (Selva>0 and Selva <39):
  print("Selva has less than 40")
else:
  print("Selva has no Money")
# Out:
# how much you have?? 50
# Selva has no Money

# %%
Selva=int(input("how much you have?? "))
if (Selva>20 and Selva <30):
  print("Selva has 20 to 30")
elif (Selva>0 and Selva <39):
  print("Selva has less than 40")
else:
  print("Selva has no Money")
